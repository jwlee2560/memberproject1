# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc # 폰트 세팅을 위한 모듈 추가

warnings.filterwarnings('ignore')

font_path = "malgun.ttf" # 사용할 폰트명 경로 삽입
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
foodSet = pd.read_csv('./Final_Cluster_Result.csv', sep=',')

# %%
# 섭취 음식 입력
# ex) 1끼 먹을 음식을 제한적인 갯수로(가령 5개 정도) 한정하여 입력하도록 조치하여 이를 일일권장량 기준의 1/3로 환산하여  
# 각 영양소에 대한 부족분을 파악하고, 이에 따라서 임력한 음식(기호 음식)을 중심으로 후보군 내에서 적합한 음식을 필터링하여 추천 음식을 선정함

# 구체적인 방안) 한끼 식사에 대한 A ~ E까지 음식이 입력되었다고 전제하고, 권장량에 충족되면 입력 그대로 진행하고 그렇지 않으면, 부족한 영양소를 A ~ E
# 음식 순으로 기호에 맞게 유사도가 가까운 음식 후보군 중에서 미달된 영양 충족하는 음식을 선정하여 추천함

# %%
inputFoods = {} # 음식(key) : 수량(value)

inputFoodA = foodSet.loc[foodSet['식품명'].str.contains('샌드위치')].iloc[0]
inputFoodA
inputFoods[inputFoodA['식품명']] = 1

# %%
inputFoodB = foodSet.loc[foodSet['식품명'].str.contains('햄버거')].iloc[0]
inputFoodB
inputFoods[inputFoodB['식품명']] = 1

# %%
inputFoodB = foodSet.loc[foodSet['식품명'].str.contains('펩시콜라')].iloc[0]
inputFoodB
inputFoods[inputFoodB['식품명']] = 1

# %%
inputFoodC = foodSet.loc[foodSet['식품명'].str.contains('감자칩')].iloc[2]
inputFoodC
inputFoods[inputFoodC['식품명']] = 1

# %%
inputFoodD = foodSet.loc[foodSet['식품명'].str.contains('신라면')].iloc[3]
inputFoodD
inputFoods[inputFoodD['식품명']] = 1

# %%
inputFoods
# Out:
# {'빵_땅콩샌드위치': 1,
#  '빵_노랑햄버거빵': 1,
#  '탄산음료_펩시콜라': 1,
#  '일반과자_트러플 감자칩': 1,
#  '라면_신라면더레드큰사발면': 1}

# %% [markdown]
# ---

# %%
import os
import cx_Oracle

# DB 한글 설정에 따른 한글 지원
# os.putenv('NLS_LANG', 'KOREAN_KOREA.KO16MSWIN949');
os.putenv('NLS_LANG', '.UTF8')

conn = cx_Oracle.connect('food', 'food', 'localhost:1521/xe')
cursor = conn.cursor()

# %%
# 성별과 나이대로 식약처 권장 영양 정보 조회
def findByGenderAndAge(gender, ageRange):

    sql_str = "select * from nutri_std_tbl where gender=:gender and age=:ageRange"
    records = cursor.execute(sql_str, [gender, ageRange])
    record = records.fetchone()

    # print('레코드 : ', record)

    # ['NUM', 'GENDER', 'AGE', 'CARBOHYDRATE', 'PROTEIN', 
    #  'SUGAR', 'NATRIUM', 'CHOLESTEROL', 'FAT', 'FATTY_ACID', 'TRANS_FATTY_ACID']
   
    return record

# 특정 나이의 나이대를 판정
# ex) 20 => 19~29
def calcAgeBand(age):
		
    result = ""
    
    ageRanges = ("6~8", "9~11", "12~14", "15~18", "19~29", "30~49", "50~64", "65~74", "75~")

    # print(ageRanges)
    
    # 리스트의 나이 최소 나이 추출하여 나이대의 최솟값의 리스트 생성
    # 나이대의 최솟값으로  6,9,12,15,19,30, .....
    ageRangeMins = [int(ageRange.split("~")[0]) for ageRange in ageRanges]
        
    # print(ageRangeMins)
    
    # 해당되는 나이(가령 20) 보다 이하 인(작거나 같은) 나이 중에서 최댓값을 구함 => 19
    tempAge = max([ageRangeMin for ageRangeMin in ageRangeMins if ageRangeMin <= age])
    
    # print("tempAge :", tempAge)
    
    # 나이대 계산
    result = [ageRange for ageRange in ageRanges if str(tempAge) in ageRange]

    # print(result[0])
        
    return result[0]

# 성별과 나이대로 식약처 권장 영양 정보 조회
def findByGenderAndAge(gender, ageRange):

    sql_str = "select * from nutri_std_tbl where gender=:gender and age=:ageRange"
    records = cursor.execute(sql_str, [gender, ageRange])
    record = records.fetchone()

    # print('레코드 : ', record)

    # ['NUM', 'GENDER', 'AGE', 'ENERGY', 'CARBOHYDRATE', 'PROTEIN', 
    #  'SUGAR', 'NATRIUM', 'CHOLESTEROL', 'FAT', 'FATTY_ACID', 'TRANS_FATTY_ACID']
   
    return record

# findByGenderAndAge('남', calcAgeBand(20))
# (5,  '남', '19~29',   2600,         130,          65,     '10~20', 1500,        300,       '15~30',          7,            1)
# 번호, 성별, 연령대, 권장열량(kcal), 탄수화물(g), 단백질(g), 지방(g), 당류(g),  나트륨(mg), 콜레스테롤(mg),  포화지방산(g), 트랜스지방(g)

# %%
# 성별, 나이, 신장, 체중, PA(Physical Activity:신체활동량)
# 영양권장량 (Recommended Dietary Allowance, RDA)

# 에너지 요구량 추정치(ESTIMATED ENERGY REQUIREMENT (EER))

# 관련 논문(근거) : https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7004509/
# https://globalrph.com/medcalcs/estimated-energy-requirement-eer-equation/
# https://www.diabetes.or.kr/general/dietary/dietary_02.php?con=2
# https://www.eatforhealth.gov.au/nutrition-calculators/daily-energy-requirements-calculator

# PA(남성) : 1.1(저활동적), 1.48(매우 활동적)
# 원문) PA = 1.0 (sedentary), 1.11 (low active), 1.25 (active), or 1.48 (very active).

# PA(여성) : 1.2(저활동적), 1.45(매우 활동적)
# 원문) PA = 1.0 (sedentary), 1.12 (low active), 1.27 (active), or 1.45 (very active).

# PA 기준안 그림 포함)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7004509/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7004509/bin/JENB_2019_v23n4_1_f001.jpg

# 한국인 영양섭취 기준 : https://www.mohw.go.kr/boardDownload.es?bid=0019&list_no=335863&seq=1

# 영양권장량(RDA) 계산
# weight(체중) : kg, 
# height(신장) : m
# EER(에너지 요구량 추정치(ESTIMATED ENERGY REQUIREMENT (EER))) : kcal
# disease(질병) : 고혈압, 당뇨, 고지혈증, 비만
def calculateRDA(disease, gender, age, height, weight, PA=1):

    #recom = [] # 권장량

    # 에너지 추정량(kcal) : ESTIMATED ENERGY REQUIREMENT (EER) EQUATION
    # 관련 논문(근거) : https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7004509/
    # https://globalrph.com/medcalcs/estimated-energy-requirement-eer-equation/
    EER = 0

    if gender == '남':
        EER = 622 - 9.53 * age + PA * (15.91 * weight + 536.6 * height)
    elif gender == '여':    
        EER = 354 - 6.91 * age + PA * (9.36 * weight + 726 * height)

    # 식약처 기준량 조회
    # 번호, 성별, 연령대, 권장열량(kcal), 탄수화물(g), 단백질(g), 지방(g), 당류(g),  나트륨(mg), 콜레스테롤(mg),  포화지방산(g), 트랜스지방(g)
    age_arange = calcAgeBand(age)
    print("연령대 : ", age_arange)
    
    nutri_tot = findByGenderAndAge(gender, age_arange)
    nutri_recomm = list(nutri_tot)
    
    # 불필요성분 제거 ex) 번호, 성별, 연령대
    nutri_recomm = nutri_recomm[3:]
    
    # 권장열량(kcal), 탄수화물(g), 단백질(g), 지방(g), 당류(g),  나트륨(mg), 콜레스테롤(mg),  포화지방산(g), 트랜스지방(g)
    print("권장 섭취량 (일반) : ", nutri_recomm)

    # 관련 근거 : https://www.ncbi.nlm.nih.gov/books/NBK218738/

    # 참고) 연도별 우리 국민의 1일 나트륨평균 섭취량 추이
    # (2022.12.31. 기준, 단위: ㎎/day, 출처: 국민건강영양조사, 질병관리청)
    
    # 연도           2011 2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
    # 나트륨 섭취량 4,831 4,583 4,027 3,890 3,890 3,669 3,478 3,274 3,289 3,220 3,080

    # 관련 근거 : 2020 한국인 영양소 섭취기준 활용 자료 개발
    # https://e-jnh.org/pdf/10.4163/jnh.2022.55.1.21
    
    # 질병이 있을 경우  ex) disease(질병) : 고혈압, 당뇨, 고지혈증, 비만

    # 참고) 고혈압의 경우 나트륨 권장량이 3700ml로 되어 있는 것은 권장량과 다르나 최근 식약처의 충분량 섭취 제개정 기준 변화로 그대로 수용
    # 나트륨 관련 규정 : 2020 한국인 영양소 섭취기준 <보건복지부, 한국영양학회> 1. 한국인 영양소 섭취기준 제·개정 요약 p. 27
    # https://www.kns.or.kr/FileRoom/FileRoom_view.asp?idx=108&BoardID=Kdr
    
    # "당뇨 환자의 탄수화물 섭취량이 많은 이유 !"
    # 당뇨에 따른 탄수화물 섭취량 관련 논문)
    #
    # "당뇨병 환자는 일반적으로 총 열량의 50~60%를 탄수화물로 섭취하도록 권고하고 있으며, 탄수화물, 단백질, 
    # 지방 섭취량은 식습관, 기호도, 치료목표 등을 고려하여 개별화할 수 있다"
    # 논문 인용) 탄수화물계산을 활용한 임상영양요법 : 김미라 분당서울대학교병원 영양실
    # : https://www.e-jkd.org/upload/pdf/jkd-2022-23-2-133.pdf

    # 참고) 당뇨 환자 일일 필요 열량 측정 프로그램 : https://www.diabetes.or.kr/general/dietary/dietary_02.php?con=2

    if (disease == '고혈압'):
        nutri_recomm[5] = 3700 # 단위 mg
        print("nutri_recomm[5] (나트륨) : ", nutri_recomm[5])
    
    if (disease == '당뇨'):
        nutri_recomm[1] = EER * 0.7 // 4 # 단위 g        
        print("nutri_recomm[1] (탄수화물) : ", nutri_recomm[1]) # 탄수화물
    
    if (disease == '고지혈증'):
        nutri_recomm[6] = EER * 0.07 // 9 # 단위 g
        print("nutri_recomm[6] (포화지방산) : ", nutri_recomm[6]) # 포화지방산

    print("권장 섭취량(유병자 적용 후) : ", nutri_recomm)

    return nutri_recomm

# %%
#calculateRDA('', '여', 20, 1.6, 50, 1.25)

# %%
#calculateRDA('고혈압', '남', 45, 1.85, 100, 1.11)

# %%
#calculateRDA('당뇨', '여', 50, 1.75, 90, 1.0)

# %%
#calculateRDA('고지혈증', '남', 20, 1.7, 70, 1.25)

# %% [markdown]
# ---

# %%
# 전체 입력 음식들에 대한 영양소 현황 집계
totFoods = pd.DataFrame(columns=['식품코드', '식품명', '에너지(kcal)', '탄수화물(g)', '단백질(g)', '지방(g)', '포화지방산(g)', '나트륨(mg)']);
print(type(totFoods))

count = 0

for foodName in inputFoods:
    
    foodRow = foodSet.loc[foodSet['식품명'] == foodName].drop_duplicates()

    # print("행수 : ", len(foodRow))
    
    if len(foodRow) == 2:
        foodRow = foodRow.head(1)

    print("수량 : ", inputFoods[foodName])

    #foodRow = foodRow * inputFoods[foodName] # 식품 * 수량 = 식품별 영양 사항
    
    foodRow['에너지(kcal)'] *= inputFoods[foodName]
    foodRow['탄수화물(g)'] *= inputFoods[foodName]
    foodRow['단백질(g)'] *= inputFoods[foodName]
    foodRow['지방(g)'] *= inputFoods[foodName]
    foodRow['포화지방산(g)'] *= inputFoods[foodName]
    foodRow['나트륨(mg)'] *= inputFoods[foodName]
    
    totFoods = pd.concat([totFoods, foodRow], ignore_index=True)
    
totFoods
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 수량 :  1
# 수량 :  1
# 수량 :  1
# 수량 :  1
# 수량 :  1
#                   식품코드            식품명 에너지(kcal)  탄수화물(g)  단백질(g)  지방(g)  \
# 0  P101-405000400-2923       빵_땅콩샌드위치       390    45.00    7.00  20.00
# 1  P101-405000400-2833       빵_노랑햄버거빵       245    40.00    4.00   4.00
# 2  P109-401040100-0554      탄산음료_펩시콜라        44    11.20    0.00   0.00
# 3  P101-106000100-2563   일반과자_트러플 감자칩       600    46.67    6.67  43.33
# 4  P108-003000400-0359  라면_신라면더레드큰사발면       444    66.67    9.40  15.38
#
#    포화지방산(g)  나트륨(mg)  Unnamed: 0 대표식품명        식품대분류명 식품중분류명 식품소분류명  \
# 0     10.00    510.0      9603.0     빵  과자류·빵류 또는 떡류   해당없음     빵류
# 1      1.00      5.0      9683.0     빵  과자류·빵류 또는 떡류   해당없음     빵류
# 2      0.00      3.0     39171.0  탄산음료           음료류  탄산음료류   탄산음료
# 3     13.33    533.0     30294.0  일반과자  과자류·빵류 또는 떡류   해당없음     과자
# 4      7.69   1436.0      6646.0    라면            면류   해당없음    유탕면
#
#    clusterLabel
# 0           2.0
# 1           0.0
# 2           1.0
# 3           2.0
# 4           3.0

# %%
# 음식에 대한 분야별 총량 계산

totFoods['에너지(kcal)'].sum()
# totFoods.describe()
# Out:
# 1723

# %%
# 일일권장 섭취량 조회
# 권장열량(kcal), 탄수화물(g), 단백질(g), 지방(g), 당류(g),  나트륨(mg), 콜레스테롤(mg),  포화지방산(g), 트랜스지방(g)
standardRDA = calculateRDA('고지혈증', '남', 53, 1.80, 96, 1.45)

disease = '고지혈증' # 병종 변수 추가
# Out:
# 연령대 :  50~64
# 권장 섭취량 (일반) :  [2200, 130, 60, '10~20', 1500, 300, '15~30', 7, 1]
# nutri_recomm[6] (포화지방산) :  29.0
# 권장 섭취량(유병자 적용 후) :  [2200, 130, 60, '10~20', 1500, 300, 29.0, 7, 1]

# %%
# 영양 결핍량 측정
# 에너지(kcal) 비교
# 영양 결핍분 집계 dataframe

nutriNeeds = {'에너지(kcal)' : [0], '탄수화물(g)' : [0], '단백질(g)' : [0], '지방(g)' : [0], '포화지방산(g)' : [0], '나트륨(mg)' : [0]}
nutriNeedsDF = pd.DataFrame(nutriNeeds, columns=['에너지(kcal)', '탄수화물(g)', '단백질(g)', '지방(g)', '포화지방산(g)', '나트륨(mg)'])

nutriNeedsDF['에너지(kcal)'] = totFoods['에너지(kcal)'].sum() - standardRDA[0]
nutriNeedsDF['탄수화물(g)']  = totFoods['탄수화물(g)'].sum() - standardRDA[1]
nutriNeedsDF['단백질(g)']    = totFoods['단백질(g)'].sum() - standardRDA[2]

#nutriNeedsDF['지방(g)']      = totFoods['지방(g)'].sum() - standardRDA[3]

# 지방 10~20
stdFat = standardRDA[3].split("~")
minFat = int(stdFat[0])
maxFat = int(stdFat[1])

#print("지방 : ", totFoods['지방(g)'].sum())

if totFoods['지방(g)'].sum() < minFat:
    nutriNeedsDF['지방(g)'] = minFat - totFoods['지방(g)'].sum()
elif totFoods['지방(g)'].sum() > maxFat:    
    nutriNeedsDF['지방(g)'] = totFoods['지방(g)'].sum() - maxFat

nutriNeedsDF['포화지방산(g)'] = totFoods['포화지방산(g)'].sum() - standardRDA[7]
nutriNeedsDF['나트륨(mg)'] = totFoods['나트륨(mg)'].sum() - standardRDA[5]

# %%
# 영양 성분 분석 결과
# 양수 이면 기준량에 대한 과잉분이 출력, 음수이면 기준량 대비 부족분으로 판단 
nutriNeedsDF
# Out:
#    에너지(kcal)  탄수화물(g)  단백질(g)  지방(g)  포화지방산(g)  나트륨(mg)
# 0       -477    79.54  -32.93  62.71     25.02   2187.0

# %% [markdown]
# ---

# %%
# foodSet.loc[0]['clusterLabel']
totFoods.iloc[0]['clusterLabel']
# Out:
# 2.0

# %%
# foodSet 중에서 
# "대표식품명" 필드에서 "환자용 식품", "고령자용 영양조제식품", "체중조절용 조제식품" 및
# "식품소분류명" 필드에서 "당뇨"이면 "당뇨환자용 영양조제식품"
# 위주로 dataframe 재구성

patientFoodDF = foodSet

#print(len(patientFoodDF))
#print(patientFoodDF.head(1))

patientFoodDF = patientFoodDF.loc[patientFoodDF['대표식품명'] == '환자용 식품']

patientFoodDF = patientFoodDF.loc[patientFoodDF['대표식품명'] == '환자용 식품']
len(patientFoodDF)

# 당뇨 환자용 # 66개
diabetesFoodDF = patientFoodDF.loc[patientFoodDF['식품명'].str.contains('당뇨')]
print(len(diabetesFoodDF))
#print(diabetesFoodDF.head())

# 암 환자용 # 3개
cancerFoodDF = patientFoodDF.loc[patientFoodDF['식품소분류명'] == '암환자용 영양조제식품']
print(len(cancerFoodDF))
# print(cancerFoodDF.head())

# 고혈압 환자용 # 4개
hypertensionFoodDF = patientFoodDF.loc[patientFoodDF['식품소분류명'].str.contains('고혈압')]
print(len(hypertensionFoodDF))
# print(hypertensionFoodDF.head())
# Out:
# 66
# 3
# 4

# %%
# 영양 결핍 부족분(값이 음수)에 따른 추천 음식 선정
# 영양 결핍 부족분(값이 음수)인 영양소 파악

#chosenDF= pd.DataFrame()

if disease == '' or disease == '고혈압' or disease == '고지혈증' : # 무병자 및 고혈압 환자, 고지혈증
    
    for nutri in nutriNeedsDF:
            
        if float(nutriNeedsDF[nutri]) < 0: # 결핍 영양소
        
            # 결핍 영양소에 따른 음식 검색
            # 입력된 음식들의 군집 범위 내에서 검색하되 첫번째 음식부터 검색
            print("부족 영양소(nutri) : ", nutri)
            print("영양소 부족분(절대값) : ", abs(float(nutriNeedsDF[nutri])))
    
            # foodSet에서 같은 클러스터의 권장 섭취분 해당 음식 검색
    
            # 과식 방지를 위해 부족분(ex. 단백질 -15.63 ==> 15.63)에 가장 가까운 값(최소값) 선정
            # 첫번째 입력 음식의 clusterLabel과 비교
            print("clusterLabel : ", totFoods.iloc[0]['clusterLabel'])
    
            # 먼저 동일한 clusterLabel을 선정 
            chosenDF = foodSet.loc[foodSet['clusterLabel'] == totFoods.iloc[0]['clusterLabel']]
            
            # 영양소 결핍분에 대한 충족 음식 조회 
            chosenDF = chosenDF.loc[foodSet[nutri] >= abs(float(nutriNeedsDF[nutri]))]
    
            print("클러스터내 추천 음식 존재 여부 : ", len(chosenDF))
            
            # 만약 환자에 해당된다면 환자에 최적화된 dataframe에서 검색        
            
            # if len(chosenDF) == 0:
            if chosenDF.empty == True:
                
                chosenDF = foodSet.loc[foodSet['clusterLabel'] != totFoods.iloc[0]['clusterLabel']]
    
                print("식품 갯수 : ", len(chosenDF))           
                print("부족분 : ", abs(float(nutriNeedsDF[nutri])))
                chosenDF = chosenDF.loc[foodSet[nutri] >= abs(float(nutriNeedsDF[nutri]))]
                
                print(chosenDF.head())        
    
            
            # 충족 음식 중 최소값 선정(과식 방지)
            print("충족 음식 중 최솟값 : ", chosenDF[nutri].min())
            print("충족 음식 중 최댓값 : ", chosenDF[nutri].max())
            chosenDF = chosenDF.loc[chosenDF[nutri] == chosenDF[nutri].min()]
            
            # 추천 음식이 다수일 경우를 위한 조치
            for idx in range(0, len(chosenDF)):
                
                print('추천 음식 : %s\n' % chosenDF.iloc[idx])        
                chosenFood = chosenDF.iloc[idx]['식품명']
                print('%s 부족분에 대한 추천 음식(들) : %s' % (nutri, chosenFood))
                print("-" * 100 + "\n")
            
        else: # 영양소 과잉에 대한 메시징
    
            print("현재 섭취하신 음식에는 %s 이(가) 권장 기준량보다 %.2f 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다."  \
                  % (nutri, float(nutriNeedsDF[nutri])))
    
            print("*" * 120)    
            
            
######## 질병별 특별 추천 #############################################################

if disease == '암':        

     for idx in range(0, len(cancerFoodDF)):
                
        chosenFood = cancerFoodDF.iloc[idx]['식품명']
        print('암환자를 위한 추천 음식(들) : %s' % chosenFood)
        print("-" * 100 + "\n")

elif disease == '고혈압':
    
    for idx in range(0, len(hypertensionFoodDF)):
             
        chosenFood = hypertensionFoodDF.iloc[idx]['식품명']
        print('고혈압 환자를 위한 대한 특별 추천 음식(들) : %s' % chosenFood)
        print("-" * 100 + "\n")

elif disease == '당뇨':        
    
    print("당뇨 환자의 경우")

    print("*" * 120)  

    for nutri in nutriNeedsDF:
            
        if float(nutriNeedsDF[nutri]) < 0: # 결핍 영양소
        
            # 결핍 영양소에 따른 음식 검색
            # 입력된 음식들의 군집 범위 내에서 검색하되 첫번째 음식부터 검색
            print("부족 영양소(nutri) : ", nutri)
            print("영양소 부족분(절대값) : ", abs(float(nutriNeedsDF[nutri])))
    
            # foodSet에서 같은 클러스터의 권장 섭취분 해당 음식 검색
    
            # 과식 방지를 위해 부족분(ex. 단백질 -15.63 ==> 15.63)에 가장 가까운 값(최소값) 선정
            # 첫번째 입력 음식의 clusterLabel과 비교
            print("clusterLabel : ", totFoods.iloc[0]['clusterLabel'])

            print(diabetesFoodDF[nutri].head())
            
            # 영양소 결핍분에 대한 충족 음식 조회
            chosenDF = diabetesFoodDF.loc[diabetesFoodDF[nutri] >= abs(float(nutriNeedsDF[nutri]))]

            #print('추천 : ', chosenDF.head())
            #print('추천 갯수 : ', len(chosenDF))
    
            # 추천할 것이 없을 경우
            if chosenDF.empty == True:

                # print('추천할 것이 없을 경우')
                
                chosenDF = diabetesFoodDF.loc[diabetesFoodDF[nutri] <= abs(float(nutriNeedsDF[nutri]))]
                print("충족 음식 중 최댓값 : ", chosenDF[nutri].max())
                chosenDF = chosenDF.loc[chosenDF[nutri] == chosenDF[nutri].max()]
                
                print("식품 갯수 : ", len(chosenDF))           
                print("부족분 : ", abs(float(nutriNeedsDF[nutri])))
                #chosenDF = chosenDF.loc[diabetesFoodDF[nutri] <= abs(float(nutriNeedsDF[nutri]))]

                print(chosenDF.head())  
                
            else :
                # 충족 음식 중 최소값 선정(과식 방지)
                print("충족 음식 중 최솟값 : ", chosenDF[nutri].min())
                print("충족 음식 중 최댓값 : ", chosenDF[nutri].max())
                chosenDF = chosenDF.loc[chosenDF[nutri] == chosenDF[nutri].min()]

                print(chosenDF.head()) 
            
                # 추천 음식이 다수일 경우를 위한 조치
                for idx in range(0, len(chosenDF)):
                    
                    print('추천 음식 : %s\n' % chosenDF.iloc[idx])        
                    chosenFood = chosenDF.iloc[idx]['식품명']
                    print('%s 부족분에 대한 추천 음식(들) : %s' % (nutri, chosenFood))
                    print("-" * 100 + "\n")
            
        else: # 영양소 과잉에 대한 메시징
    
            print("현재 섭취하신 음식에는 %s 이(가) 권장 기준량보다 %.2f 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다."  \
                  % (nutri, float(nutriNeedsDF[nutri])))
    
            #print("*" * 120)

        print("\n" + "#" * 120 + "\n")
# Out:
# 부족 영양소(nutri) :  에너지(kcal)
# 영양소 부족분(절대값) :  477.0
# clusterLabel :  2.0
# 클러스터내 추천 음식 존재 여부 :  6588
# 충족 음식 중 최솟값 :  477
# 충족 음식 중 최댓값 :  980
# 추천 음식 : Unnamed: 0                     2236
# 식품코드            P109-202020000-0062
# 식품명               인스턴트커피_비니스트 카페 라떼
# 대표식품명                        인스턴트커피
# 식품대분류명                          음료류
# 식품중분류명                           커피
# 식품소분류명                         해당없음
# 에너지(kcal)                       477
# 탄수화물(g)                       61.54
# 단백질(g)                         7.69
# 지방(g)                         23.08
# 포화지방산(g)                      19.23
# 나트륨(mg)                       362.0
# clusterLabel                      2
# Name: 2236, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 인스턴트커피_비니스트 카페 라떼
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     7168
# 식품코드            P103-101020500-0626
# 식품명                 초콜릿_아이파베스다크생초콜릿
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                       초콜릿가공품
# 에너지(kcal)                       477
# 탄수화물(g)                       40.05
# 단백질(g)                         5.35
# 지방(g)                         32.82
# 포화지방산(g)                      21.59
# 나트륨(mg)                        86.0
# clusterLabel                      2
# Name: 7168, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_아이파베스다크생초콜릿
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     7627
# 식품코드            P103-101020500-0167
# 식품명                초콜릿_달모어싱글오리진생초콜릿
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                       초콜릿가공품
# 에너지(kcal)                       477
# 탄수화물(g)                       40.06
# 단백질(g)                         5.35
# 지방(g)                         32.82
# 포화지방산(g)                      21.59
# 나트륨(mg)                        86.0
# clusterLabel                      2
# Name: 7627, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_달모어싱글오리진생초콜릿
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     7703
# 식품코드            P103-101020500-0106
# 식품명             초콜릿_꼬르지엘모유기농우유밀크생초코
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                       초콜릿가공품
# 에너지(kcal)                       477
# 탄수화물(g)                       47.17
# 단백질(g)                         7.18
# 지방(g)                         28.82
# 포화지방산(g)                      17.32
# 나트륨(mg)                        86.0
# clusterLabel                      2
# Name: 7703, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_꼬르지엘모유기농우유밀크생초코
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                      7798
# 식품코드             P103-101020500-0001
# 식품명             초콜릿_[홀랜드앤바렛)초키피넛앤레이즌
# 대표식품명                            초콜릿
# 식품대분류명               코코아가공품류 또는 초콜릿류
# 식품중분류명                          초콜릿류
# 식품소분류명                        초콜릿가공품
# 에너지(kcal)                        477
# 탄수화물(g)                         54.0
# 단백질(g)                           9.0
# 지방(g)                           25.0
# 포화지방산(g)                        11.0
# 나트륨(mg)                         40.0
# clusterLabel                       2
# Name: 7798, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_[홀랜드앤바렛)초키피넛앤레이즌
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     8683
# 식품코드            P103-101020100-0378
# 식품명                    초콜릿_초코칩다크309
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                          초콜릿
# 에너지(kcal)                       477
# 탄수화물(g)                        57.0
# 단백질(g)                          6.0
# 지방(g)                          25.0
# 포화지방산(g)                       16.0
# 나트륨(mg)                         3.0
# clusterLabel                      2
# Name: 8683, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_초코칩다크309
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     8789
# 식품코드            P103-101020100-0280
# 식품명                      초콜릿_스노우쇼콜라
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                          초콜릿
# 에너지(kcal)                       477
# 탄수화물(g)                       46.67
# 단백질(g)                          5.0
# 지방(g)                          30.0
# 포화지방산(g)                      13.33
# 나트륨(mg)                        65.0
# clusterLabel                      2
# Name: 8789, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_스노우쇼콜라
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     8967
# 식품코드            P103-101020100-0119
# 식품명                 초콜릿_다크초콜릿커버춰이나야
# 대표식품명                           초콜릿
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                          초콜릿
# 에너지(kcal)                       477
# 탄수화물(g)                        36.0
# 단백질(g)                          9.0
# 지방(g)                          33.0
# 포화지방산(g)                       20.0
# 나트륨(mg)                         8.0
# clusterLabel                      2
# Name: 8967, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿_다크초콜릿커버춰이나야
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    11168
# 식품코드            P101-405000400-3666
# 식품명                 빵_컵넛 초코 버터바(완제)
# 대표식품명                             빵
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       60.03
# 단백질(g)                         4.47
# 지방(g)                         24.33
# 포화지방산(g)                      14.65
# 나트륨(mg)                       130.0
# clusterLabel                      2
# Name: 11168, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 빵_컵넛 초코 버터바(완제)
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    11262
# 식품코드            P101-405000400-3590
# 식품명                    빵_초코 버터바(완제)
# 대표식품명                             빵
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       60.03
# 단백질(g)                         4.47
# 지방(g)                         24.33
# 포화지방산(g)                      14.65
# 나트륨(mg)                       130.0
# clusterLabel                      2
# Name: 11262, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 빵_초코 버터바(완제)
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    18054
# 식품코드            P101-412000400-0062
# 식품명                  타르트_제주리얼타르트한라봉
# 대표식품명                           타르트
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       62.86
# 단백질(g)                         2.86
# 지방(g)                         22.86
# 포화지방산(g)                      14.29
# 나트륨(mg)                       186.0
# clusterLabel                      2
# Name: 16465, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 타르트_제주리얼타르트한라봉
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    18372
# 식품코드            P101-410000400-0091
# 식품명                 크로와상_아망딘꽈배기크루아상
# 대표식품명                          크로와상
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       54.44
# 단백질(g)                         8.67
# 지방(g)                         25.11
# 포화지방산(g)                      11.22
# 나트륨(mg)                       261.0
# clusterLabel                      2
# Name: 16783, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 크로와상_아망딘꽈배기크루아상
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    20506
# 식품코드            P103-102020500-0320
# 식품명                 초콜릿과자_프로틴초코볼아몬드
# 대표식품명                         초콜릿과자
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                       초콜릿가공품
# 에너지(kcal)                       477
# 탄수화물(g)                       36.67
# 단백질(g)                        23.33
# 지방(g)                         36.67
# 포화지방산(g)                      13.33
# 나트륨(mg)                        83.0
# clusterLabel                      2
# Name: 17900, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿과자_프로틴초코볼아몬드
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    20698
# 식품코드            P103-102020500-0126
# 식품명                  초콜릿과자_미니초콜릿칩쿠키
# 대표식품명                         초콜릿과자
# 식품대분류명              코코아가공품류 또는 초콜릿류
# 식품중분류명                         초콜릿류
# 식품소분류명                       초콜릿가공품
# 에너지(kcal)                       477
# 탄수화물(g)                        62.0
# 단백질(g)                          5.5
# 지방(g)                          23.0
# 포화지방산(g)                       12.0
# 나트륨(mg)                       380.0
# clusterLabel                      2
# Name: 18092, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 초콜릿과자_미니초콜릿칩쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    29916
# 식품코드            P101-107000100-0263
# 식품명                    전통과자_초코유과크런치
# 대표식품명                          전통과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       70.55
# 단백질(g)                         10.0
# 지방(g)                         19.16
# 포화지방산(g)                      16.79
# 나트륨(mg)                       176.0
# clusterLabel                      2
# Name: 27309, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 전통과자_초코유과크런치
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    30038
# 식품코드            P101-107000100-0147
# 식품명                  전통과자_밀크초코유과크런치
# 대표식품명                          전통과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                        75.0
# 단백질(g)                          0.0
# 지방(g)                         16.67
# 포화지방산(g)                      16.67
# 나트륨(mg)                       204.0
# clusterLabel                      2
# Name: 27431, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 전통과자_밀크초코유과크런치
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    30505
# 식품코드            P101-106000100-2333
# 식품명               일반과자_아넬라 롱떡뻥 딸기우유
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       67.29
# 단백질(g)                         9.65
# 지방(g)                         18.75
# 포화지방산(g)                      10.36
# 나트륨(mg)                       176.0
# clusterLabel                      2
# Name: 27898, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_아넬라 롱떡뻥 딸기우유
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    30540
# 식품코드            P101-106000100-2301
# 식품명              일반과자_샤인머스켓,순우유,인절미
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                        46.7
# 단백질(g)                         5.85
# 지방(g)                         29.65
# 포화지방산(g)                      16.47
# 나트륨(mg)                        58.0
# clusterLabel                      2
# Name: 27933, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_샤인머스켓,순우유,인절미
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    30630
# 식품코드            P101-106000100-0001
# 식품명                  일반과자_(증식용)야채건빵
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       69.23
# 단백질(g)                         9.23
# 지방(g)                         18.46
# 포화지방산(g)                       9.23
# 나트륨(mg)                       338.0
# clusterLabel                      2
# Name: 28023, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_(증식용)야채건빵
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                            30910
# 식품코드                    P101-103000400-2323
# 식품명             비스킷/쿠키/크래커_화이트마카다미아쿠키생지(냉동)
# 대표식품명                            비스킷/쿠키/크래커
# 식품대분류명                         과자류·빵류 또는 떡류
# 식품중분류명                                 해당없음
# 식품소분류명                                   빵류
# 에너지(kcal)                               477
# 탄수화물(g)                               64.29
# 단백질(g)                                 6.19
# 지방(g)                                  21.7
# 포화지방산(g)                              10.67
# 나트륨(mg)                               415.0
# clusterLabel                              2
# Name: 28303, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_화이트마카다미아쿠키생지(냉동)
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                        31534
# 식품코드                P101-103000400-1692
# 식품명             비스킷/쿠키/크래커_크리스마스넛크래커비스킷
# 대표식품명                        비스킷/쿠키/크래커
# 식품대분류명                     과자류·빵류 또는 떡류
# 식품중분류명                             해당없음
# 식품소분류명                               빵류
# 에너지(kcal)                           477
# 탄수화물(g)                            53.7
# 단백질(g)                              5.5
# 지방(g)                              27.5
# 포화지방산(g)                           13.9
# 나트륨(mg)                           200.0
# clusterLabel                          2
# Name: 28927, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_크리스마스넛크래커비스킷
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    31686
# 식품코드            P101-103000400-1550
# 식품명                 비스킷/쿠키/크래커_커피쿠키
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                        70.0
# 단백질(g)                         6.67
# 지방(g)                          20.0
# 포화지방산(g)                       6.67
# 나트륨(mg)                       157.0
# clusterLabel                      2
# Name: 29079, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_커피쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    31827
# 식품코드            P101-103000400-1398
# 식품명              비스킷/쿠키/크래커_초코초코칩쿠키
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       63.33
# 단백질(g)                         3.33
# 지방(g)                         23.33
# 포화지방산(g)                       9.33
# 나트륨(mg)                       233.0
# clusterLabel                      2
# Name: 29220, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_초코초코칩쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    31844
# 식품코드            P101-103000400-1382
# 식품명              비스킷/쿠키/크래커_초코사브레쿠키
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       45.56
# 단백질(g)                         5.56
# 지방(g)                          30.0
# 포화지방산(g)                      15.56
# 나트륨(mg)                         7.0
# clusterLabel                      2
# Name: 29237, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_초코사브레쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     32002
# 식품코드             P101-103000400-1252
# 식품명             비스킷/쿠키/크래커_이더블크렌베리쿠키
# 대표식품명                     비스킷/쿠키/크래커
# 식품대분류명                  과자류·빵류 또는 떡류
# 식품중분류명                          해당없음
# 식품소분류명                            빵류
# 에너지(kcal)                        477
# 탄수화물(g)                        62.86
# 단백질(g)                          5.71
# 지방(g)                           20.0
# 포화지방산(g)                        8.57
# 나트륨(mg)                         54.0
# clusterLabel                       2
# Name: 29395, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_이더블크렌베리쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                         32119
# 식품코드                 P101-103000400-1113
# 식품명             비스킷/쿠키/크래커_오케비스 딸기 크림 쿠키
# 대표식품명                         비스킷/쿠키/크래커
# 식품대분류명                      과자류·빵류 또는 떡류
# 식품중분류명                              해당없음
# 식품소분류명                                빵류
# 에너지(kcal)                            477
# 탄수화물(g)                             72.7
# 단백질(g)                               4.5
# 지방(g)                               20.5
# 포화지방산(g)                            10.2
# 나트륨(mg)                            193.0
# clusterLabel                           2
# Name: 29512, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_오케비스 딸기 크림 쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                           32120
# 식품코드                   P101-103000400-1114
# 식품명             비스킷/쿠키/크래커_오케비스 초코말트 크림 쿠키
# 대표식품명                           비스킷/쿠키/크래커
# 식품대분류명                        과자류·빵류 또는 떡류
# 식품중분류명                                해당없음
# 식품소분류명                                  빵류
# 에너지(kcal)                              477
# 탄수화물(g)                               72.7
# 단백질(g)                                 4.5
# 지방(g)                                 20.5
# 포화지방산(g)                              10.2
# 나트륨(mg)                              148.0
# clusterLabel                             2
# Name: 29513, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_오케비스 초코말트 크림 쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    32263
# 식품코드            P101-103000400-0966
# 식품명               비스킷/쿠키/크래커_안나생강맛틴
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                        70.0
# 단백질(g)                         5.33
# 지방(g)                         19.33
# 포화지방산(g)                       9.33
# 나트륨(mg)                       480.0
# clusterLabel                      2
# Name: 29656, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_안나생강맛틴
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    32264
# 식품코드            P101-103000400-0967
# 식품명              비스킷/쿠키/크래커_안나오렌지맛틴
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                        70.0
# 단백질(g)                         5.33
# 지방(g)                         19.33
# 포화지방산(g)                       9.33
# 나트륨(mg)                       480.0
# clusterLabel                      2
# Name: 29657, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_안나오렌지맛틴
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    32265
# 식품코드            P101-103000400-0968
# 식품명             비스킷/쿠키/크래커_안나카푸치노향틴
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                        70.0
# 단백질(g)                         5.33
# 지방(g)                         19.33
# 포화지방산(g)                       9.33
# 나트륨(mg)                       480.0
# clusterLabel                      2
# Name: 29658, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_안나카푸치노향틴
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     32384
# 식품코드             P101-103000400-0861
# 식품명             비스킷/쿠키/크래커_스노우라이스쌀과자
# 대표식품명                     비스킷/쿠키/크래커
# 식품대분류명                  과자류·빵류 또는 떡류
# 식품중분류명                          해당없음
# 식품소분류명                            빵류
# 에너지(kcal)                        477
# 탄수화물(g)                         74.6
# 단백질(g)                           4.7
# 지방(g)                           17.8
# 포화지방산(g)                         8.6
# 나트륨(mg)                        205.0
# clusterLabel                       2
# Name: 29777, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_스노우라이스쌀과자
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    32656
# 식품코드            P101-103000400-0587
# 식품명             비스킷/쿠키/크래커_바닐라초코칩쿠키
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       477
# 탄수화물(g)                       63.33
# 단백질(g)                         3.33
# 지방(g)                         23.33
# 포화지방산(g)                       8.67
# 나트륨(mg)                       233.0
# clusterLabel                      2
# Name: 30049, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_바닐라초코칩쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    33278
# 식품코드            P101-106000100-1830
# 식품명                    일반과자_토르세티알브로
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                        63.0
# 단백질(g)                          4.5
# 지방(g)                          23.0
# 포화지방산(g)                       15.0
# 나트륨(mg)                       300.0
# clusterLabel                      2
# Name: 30671, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_토르세티알브로
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    34111
# 식품코드            P101-106000100-0996
# 식품명                   일반과자_서주진짜고구마칩
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       74.29
# 단백질(g)                          0.0
# 지방(g)                          20.0
# 포화지방산(g)                       8.86
# 나트륨(mg)                        74.0
# clusterLabel                      2
# Name: 31504, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_서주진짜고구마칩
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    34469
# 식품코드            P101-106000100-0606
# 식품명                   일반과자_마가렛트씨앗호떡
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       59.09
# 단백질(g)                         4.55
# 지방(g)                         22.73
# 포화지방산(g)                      12.73
# 나트륨(mg)                       114.0
# clusterLabel                      2
# Name: 31862, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_마가렛트씨앗호떡
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     34487
# 식품코드             P101-106000100-0590
# 식품명             일반과자_리지스그라놀라핑크애플&시나몬
# 대표식품명                           일반과자
# 식품대분류명                  과자류·빵류 또는 떡류
# 식품중분류명                          해당없음
# 식품소분류명                            과자
# 에너지(kcal)                        477
# 탄수화물(g)                         48.0
# 단백질(g)                          10.4
# 지방(g)                           27.0
# 포화지방산(g)                         6.0
# 나트륨(mg)                         86.0
# clusterLabel                       2
# Name: 31880, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_리지스그라놀라핑크애플&시나몬
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    34907
# 식품코드            P101-106000100-0189
# 식품명                      일반과자_구마구마해
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       66.67
# 단백질(g)                         3.51
# 지방(g)                         22.81
# 포화지방산(g)                       6.67
# 나트륨(mg)                        49.0
# clusterLabel                      2
# Name: 32300, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 일반과자_구마구마해
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     35635
# 식품코드             P101-103000400-0047
# 식품명             비스킷/쿠키/크래커_감자칩김&와사비향
# 대표식품명                     비스킷/쿠키/크래커
# 식품대분류명                  과자류·빵류 또는 떡류
# 식품중분류명                          해당없음
# 식품소분류명                            빵류
# 에너지(kcal)                        477
# 탄수화물(g)                        59.09
# 단백질(g)                          4.55
# 지방(g)                          24.55
# 포화지방산(g)                       10.91
# 나트륨(mg)                        773.0
# clusterLabel                       2
# Name: 33028, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_감자칩김&와사비향
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                      35799
# 식품코드              P101-103000100-0355
# 식품명             비스킷/쿠키/크래커_쫀득샌드쿠키_황치즈
# 대표식품명                      비스킷/쿠키/크래커
# 식품대분류명                   과자류·빵류 또는 떡류
# 식품중분류명                           해당없음
# 식품소분류명                             과자
# 에너지(kcal)                         477
# 탄수화물(g)                         58.73
# 단백질(g)                            1.0
# 지방(g)                           25.26
# 포화지방산(g)                        14.48
# 나트륨(mg)                         311.0
# clusterLabel                        2
# Name: 33192, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_쫀득샌드쿠키_황치즈
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                           35814
# 식품코드                   P101-103000100-0338
# 식품명             비스킷/쿠키/크래커_이웃집 통통이 황치즈약과쿠키
# 대표식품명                           비스킷/쿠키/크래커
# 식품대분류명                        과자류·빵류 또는 떡류
# 식품중분류명                                해당없음
# 식품소분류명                                  과자
# 에너지(kcal)                              477
# 탄수화물(g)                              66.67
# 단백질(g)                                5.83
# 지방(g)                                20.83
# 포화지방산(g)                              10.0
# 나트륨(mg)                              326.0
# clusterLabel                             2
# Name: 33207, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_이웃집 통통이 황치즈약과쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                      35831
# 식품코드              P101-103000100-0323
# 식품명             비스킷/쿠키/크래커_우유 샌드 쿠키 Q
# 대표식품명                      비스킷/쿠키/크래커
# 식품대분류명                   과자류·빵류 또는 떡류
# 식품중분류명                           해당없음
# 식품소분류명                             과자
# 에너지(kcal)                         477
# 탄수화물(g)                          43.0
# 단백질(g)                            5.0
# 지방(g)                            32.0
# 포화지방산(g)                         22.0
# 나트륨(mg)                          58.0
# clusterLabel                        2
# Name: 33224, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_우유 샌드 쿠키 Q
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    35873
# 식품코드            P101-103000100-0301
# 식품명             비스킷/쿠키/크래커_옐로우 약과쿠키
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       66.67
# 단백질(g)                         5.83
# 지방(g)                         20.83
# 포화지방산(g)                       10.0
# 나트륨(mg)                       326.0
# clusterLabel                      2
# Name: 33266, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_옐로우 약과쿠키
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    36378
# 식품코드            P101-102000100-0253
# 식품명                   마카롱_초코뚱카롱(3종)
# 대표식품명                           마카롱
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       66.67
# 단백질(g)                         6.67
# 지방(g)                          20.0
# 포화지방산(g)                       10.0
# 나트륨(mg)                        60.0
# clusterLabel                      2
# Name: 33771, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 마카롱_초코뚱카롱(3종)
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    36662
# 식품코드            P101-101000100-0155
# 식품명             강냉이/팝콘_프레즐앤팝콘초콜릿&솔트
# 대표식품명                        강냉이/팝콘
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       477
# 탄수화물(g)                       73.85
# 단백질(g)                         4.62
# 지방(g)                         18.46
# 포화지방산(g)                       9.23
# 나트륨(mg)                       662.0
# clusterLabel                      2
# Name: 34055, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 강냉이/팝콘_프레즐앤팝콘초콜릿&솔트
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                      36663
# 식품코드              P101-101000100-0156
# 식품명             강냉이/팝콘_프레즐앤팝콘카라멜&체다치즈
# 대표식품명                          강냉이/팝콘
# 식품대분류명                   과자류·빵류 또는 떡류
# 식품중분류명                           해당없음
# 식품소분류명                             과자
# 에너지(kcal)                         477
# 탄수화물(g)                         73.85
# 단백질(g)                           4.62
# 지방(g)                           18.46
# 포화지방산(g)                         9.23
# 나트륨(mg)                         662.0
# clusterLabel                        2
# Name: 34056, dtype: object
#
# 에너지(kcal) 부족분에 대한 추천 음식(들) : 강냉이/팝콘_프레즐앤팝콘카라멜&체다치즈
# ----------------------------------------------------------------------------------------------------
#
# 현재 섭취하신 음식에는 탄수화물(g) 이(가) 권장 기준량보다 79.54 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다.
# ************************************************************************************************************************
# 부족 영양소(nutri) :  단백질(g)
# 영양소 부족분(절대값) :  32.93
# clusterLabel :  2.0
# 클러스터내 추천 음식 존재 여부 :  0
# 식품 갯수 :  33920
# 부족분 :  32.93
#       Unnamed: 0                 식품코드                      식품명 대표식품명 식품대분류명  \
# 2688        2688  P109-201020000-0560                액상커피_디카페인  액상커피    음료류
# 3300        3300  P109-103010300-0210  분말차_프리티 스파클링 아르기닌 샤인머스캣   분말차    음료류
# 3301        3301  P109-103010300-0211     분말차_프리티 스파클링 아르기닌 푸룬   분말차    음료류
# 5776        5776  P108-010000300-0029             쌀국수_블랙소이빈누들칩   쌀국수     면류
# 5782        5782  P108-010000300-0035               쌀국수_소이빈누들칩   쌀국수     면류
#
#      식품중분류명 식품소분류명  에너지(kcal)  탄수화물(g)  단백질(g)  지방(g)  포화지방산(g)  나트륨(mg)  \
# 2688     커피   해당없음       1000    50.00   50.00   50.0       0.0      0.0
# 3300     다류    고형차        355    27.27   63.64    0.0       0.0   3355.0
# 3301     다류    고형차        364    27.27   63.64    0.0       0.0   3091.0
# 5776   해당없음     건면        395    35.50   42.30    9.4       8.0      1.0
# 5782   해당없음     건면        395    35.50   42.30    9.4       8.0      1.0
#
#       clusterLabel
# 2688             4
# 3300             4
# 3301             4
# 5776             4
# 5782             4
# 충족 음식 중 최솟값 :  33.0
# 충족 음식 중 최댓값 :  100.0
# 추천 음식 : Unnamed: 0                    16370
# 식품코드            P101-403000400-0210
# 식품명                 바게트/치아바타_플레인바게트
# 대표식품명                      바게트/치아바타
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       588
# 탄수화물(g)                        53.0
# 단백질(g)                         33.0
# 지방(g)                          27.0
# 포화지방산(g)                        9.0
# 나트륨(mg)                       524.0
# clusterLabel                      4
# Name: 14783, dtype: object
#
# 단백질(g) 부족분에 대한 추천 음식(들) : 바게트/치아바타_플레인바게트
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    31132
# 식품코드            P101-103000400-2095
# 식품명                 비스킷/쿠키/크래커_향라완두
# 대표식품명                    비스킷/쿠키/크래커
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           빵류
# 에너지(kcal)                       423
# 탄수화물(g)                        37.0
# 단백질(g)                         33.0
# 지방(g)                          16.0
# 포화지방산(g)                        0.0
# 나트륨(mg)                       600.0
# clusterLabel                      4
# Name: 28525, dtype: object
#
# 단백질(g) 부족분에 대한 추천 음식(들) : 비스킷/쿠키/크래커_향라완두
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    34136
# 식품코드            P101-106000100-0953
# 식품명                       일반과자_산향완두
# 대표식품명                          일반과자
# 식품대분류명                 과자류·빵류 또는 떡류
# 식품중분류명                         해당없음
# 식품소분류명                           과자
# 에너지(kcal)                       423
# 탄수화물(g)                        37.0
# 단백질(g)                         33.0
# 지방(g)                          16.0
# 포화지방산(g)                        0.0
# 나트륨(mg)                       600.0
# clusterLabel                      4
# Name: 31529, dtype: object
#
# 단백질(g) 부족분에 대한 추천 음식(들) : 일반과자_산향완두
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                    47658
# 식품코드            P114-400020100-0050
# 식품명                 절임식품_모티 달콤 황태무침
# 대표식품명                          절임식품
# 식품대분류명                   절임류 또는 조림류
# 식품중분류명                          절임류
# 식품소분류명                         절임식품
# 에너지(kcal)                       280
# 탄수화물(g)                        22.0
# 단백질(g)                         33.0
# 지방(g)                           7.0
# 포화지방산(g)                        1.1
# 나트륨(mg)                       700.0
# clusterLabel                      4
# Name: 42854, dtype: object
#
# 단백질(g) 부족분에 대한 추천 음식(들) : 절임식품_모티 달콤 황태무침
# ----------------------------------------------------------------------------------------------------
#
# 추천 음식 : Unnamed: 0                     48289
# 식품코드             P116-400070200-0005
# 식품명             시리얼_Gr+ 프로틴 그래놀라 시나몬
# 대표식품명                            시리얼
# 식품대분류명                       농산가공식품류
# 식품중분류명                     기타 농산가공품류
# 식품소분류명                         곡류가공품
# 에너지(kcal)                        441
# 탄수화물(g)                         50.0
# 단백질(g)                          33.0
# 지방(g)                           12.0
# 포화지방산(g)                         5.0
# 나트륨(mg)                        376.0
# clusterLabel                       4
# Name: 43485, dtype: object
#
# 단백질(g) 부족분에 대한 추천 음식(들) : 시리얼_Gr+ 프로틴 그래놀라 시나몬
# ----------------------------------------------------------------------------------------------------
#
# 현재 섭취하신 음식에는 지방(g) 이(가) 권장 기준량보다 62.71 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다.
# ************************************************************************************************************************
# 현재 섭취하신 음식에는 포화지방산(g) 이(가) 권장 기준량보다 25.02 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다.
# ************************************************************************************************************************
# 현재 섭취하신 음식에는 나트륨(mg) 이(가) 권장 기준량보다 2187.00 만큼 과다합니다. 추후 조절하여 섭취하시기 바랍니다.
# ************************************************************************************************************************

# %%
cursor.close()
conn.close()
